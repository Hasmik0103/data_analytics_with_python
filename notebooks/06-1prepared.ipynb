# %%
#gitup download
import pandas as pd
SQL_URL="https://raw.githubusercontent.com/Hasmik0103/sql-analytics-portfolio/refs/heads/main/data/public_schema/"
To_SAVE_URL='C:/Users/Sargsyan/Desktop/aca/sql-analytics-portfolio/data/public_schema/'
l=['customers','employees','orders','products','sales']
for i in l:
    print(100*'-')
    print (f"trying to download {i}.csv")
    print(SQL_URL+i+'.csv')
    df=pd.read_csv(SQL_URL+i+'.csv')
    print(f"{i}.csv is downloaded")
    print(f"the shape of {i}.cvs:{df.shape}")
    print(f"trying to save {i}.csv")
    df.to_csv(To_SAVE_URL+i+'.csv',index=False)
    print(f"{i}.csv is successfully saved")
# Out:
# ----------------------------------------------------------------------------------------------------
# trying to download customers.csv
# https://raw.githubusercontent.com/Hasmik0103/sql-analytics-portfolio/refs/heads/main/data/public_schema/customers.csv
# customers.csv is downloaded
# the shape of customers.cvs:(2000, 5)
# trying to save customers.csv
# customers.csv is successfully saved
# ----------------------------------------------------------------------------------------------------
# trying to download employees.csv
# https://raw.githubusercontent.com/Hasmik0103/sql-analytics-portfolio/refs/heads/main/data/public_schema/employees.csv
# employees.csv is downloaded
# the shape of employees.cvs:(100, 5)
# trying to save employees.csv
# employees.csv is successfully saved
# ----------------------------------------------------------------------------------------------------
# trying to download orders.csv
# ...

# %%
import zipfile
with zipfile.ZipFile("../data/raw/order_products_prior.parquet.zip", "r") as zip_ref:
    zip_ref.extractall("../data/raw")

# %%
df_parquets = pd.read_parquet('../data/raw/order_products_prior.parquet')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df_parquets = pd.read_parquet('../data/raw/order_products_prior.parquet')
#
# File c:\Users\Sargsyan\miniconda3\envs\aca\Lib\site-packages\pandas\io\parquet.py:668, in read_parquet(path, engine, columns, storage_options, dtype_backend, filesystem, filters, to_pandas_kwargs, **kwargs)
#     508 @set_module("pandas")
#     509 def read_parquet(
#     510     path: FilePath | ReadBuffer[bytes],
#    (...)    518     **kwargs,
#     519 ) -> DataFrame:
#     520     """
#     521     Load a parquet object from the file path, returning a DataFrame.
#     522
#    (...)    665     1    4    9
#     666     """
# --> 668     impl = get_engine(engine)
#     669     check_dtype_backend(dtype_backend)
#     671     return impl.read(
#     672         path,
#     673         columns=columns,
# ...

# %%
import pandas as pd
